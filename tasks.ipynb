# %% [markdown]
# # Task 3.

# %% [markdown]
# ## 3.You should be able to plot something, and after showing the plot, add something to the same plot (without deleting the previous plot).

# %%
import os
import sys
sys.path.append('..')
from scipy.io import wavfile
import settings
import soundanalysis
import sound_files
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import scipy
from scipy import stats
from IPython.display import Audio


filename1 = os.path.join(settings.SOUNDS_PATH, 'heavy_rain.wav')

sound_files.clip(filename1, filename1.replace(".wav", "_snippet1.wav"), 0, 60)
filename1_snippet1 = os.path.join(settings.SOUNDS_PATH, 'heavy_rain_snippet1.wav')
frequency1, data1 = wavfile.read(filename1_snippet1)

sound_files.clip(filename1, filename1.replace(".wav", "_snippet2.wav"), 60, 120)
filename1_snippet2 = os.path.join(settings.SOUNDS_PATH, 'heavy_rain_snippet2.wav')
frequency2, data2 = wavfile.read(filename1_snippet2)

data_sound1_float = data1.astype(np.float)
data_sound2_float = data2.astype(np.float)

sns.distplot(data_sound1_float, hist=False, color="deepskyblue", label="sound1")

# %%
sns.distplot(data_sound1_float, hist=False, color="deepskyblue", label="sound1")
sns.distplot(data_sound2_float,hist=False, color="darkslategray", label="sound2")
